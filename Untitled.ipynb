# %%
with open(".gitignore", "w") as f:
    f.write(
"""assamese_data/
cnn_data/images_128/
*.rar
__pycache__/
.ipynb_checkpoints/
"""
)

print(".gitignore created")
# Out:
# .gitignore created

# %%
import os
os.listdir()
# Out:
# ['cnn_data',
#  'Untitled.ipynb',
#  'Online Handwritten Assamese Characters Dataset.rar',
#  '.gitignore',
#  'final_proj.ipynb',
#  'assamese_data',
#  '.ipynb_checkpoints']

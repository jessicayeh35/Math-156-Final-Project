# %%
import os
os.getcwd()
# Out:
# '/Users/jessica/Documents/WINTER 2026/MATH 156/FInal Project'

# %%
import rarfile

rar_path = "/Users/jessica/Documents/WINTER 2026/MATH 156/FInal Project/Online Handwritten Assamese Characters Dataset.rar"   # change to your file name
extract_path = "assamese_data"  # folder to extract into

with rarfile.RarFile(rar_path) as rf:
    rf.extractall(extract_path)

print("Extraction complete!")
# Out:
# ---------------------------------------------------------------------------
# BadRarFile                                Traceback (most recent call last)
# Cell In[3], line 7
#       4 extract_path = "assamese_data"  # folder to extract into
#       6 with rarfile.RarFile(rar_path) as rf:
# ----> 7     rf.extractall(extract_path)
#       9 print("Extraction complete!")
#
# File /opt/anaconda3/lib/python3.13/site-packages/rarfile.py:886, in RarFile.extractall(self, path, members, pwd)
#     884 for m in members:
#     885     inf = self.getinfo(m)
# --> 886     dst = self._extract_one(inf, path, pwd, not inf.is_dir())
#     887     if inf.is_dir():
#     888         if dst not in done:
#
# File /opt/anaconda3/lib/python3.13/site-packages/rarfile.py:951, in RarFile._extract_one(self, info, path, pwd, set_attrs)
#     948     os.makedirs(dirname, exist_ok=True)
#     950 if info.is_file():
# --> 951     return self._make_file(info, dstfn, pwd, set_attrs)
#     952 if info.is_dir():
# ...
